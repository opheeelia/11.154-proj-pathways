# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px

# %%
df = pd.read_excel("./naturalDisasters.xlsx")[['Year', 'Disaster Type', 'Event Name', 'Country', 'Total Affected']]
display(df)
df.to_csv('./naturalDisasters.csv')
# Out:
#      Year       Disaster Type                Event Name    Country  \
# 0    2000               Storm                     Keith     Belize
# 1    2000               Flood                       NaN  Guatemala
# 2    2000               Flood                       NaN     Mexico
# 3    2000             Drought                       NaN   Honduras
# 4    2000             Drought                       NaN  Nicaragua
# ..    ...                 ...                       ...        ...
# 545  2019               Storm  Tropical storm 'Fernand'     Mexico
# 546  2019  Transport accident                       NaN  Guatemala
# 547  2019               Storm    Tropical storm 'Narda'     Mexico
# 548  2019  Transport accident                       NaN     Mexico
# 549  2019               Flood                       NaN     Mexico
#
#      Total Affected
# 0           62570.0
# 1             462.0
# 2               NaN
# 3            1125.0
# 4               NaN
# ..              ...
# ...

# %%
conflict_df = pd.read_csv("./conflict.csv")[['year', 'country']]
conflict_df = conflict_df.groupby(by='year').count().reset_index()
display(conflict_df)
# Out:
#    year  country
# 0  2018    17215
# 1  2019    18168
